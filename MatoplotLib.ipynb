# %% [markdown]
# # Types of Data
# - Numerical Data
# - Categorical Data

# %%
# import the library
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 
import seaborn as sns

# %% [markdown]
# # 2D Line plot
# - Bivariate Analysis
# - categorical -> numerical and numerical -> numerical
# - Use case - Time series data

# %%
# plotting a simple function
x = [1,2,3,4,5,6,7,8]
y = [10,22,5,47,89,63,56, 40]
plt.plot(x , y)
plt.show()

# %%
# from a pandas dataframe (use sharma-kohli dataset )
df = pd.read_csv('./Datasets/sharma-kohli.csv')
df.head()
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
plt.plot(df['index'], df['RG Sharma'] )

# %%
plt.plot(df['index'], df['V Kohli'])

# %%
# plotting multiple plots
plt.plot(df['index'], df['V Kohli'])
plt.plot(df['index'], df['RG Sharma'])

# %%
# labels and title
plt.plot(df['index'], df['V Kohli'])
plt.plot(df['index'], df['RG Sharma'])
plt.xlabel("Year")
plt.ylabel('Total Runs')
plt.title('Virat Kohali and Rohit Sharma Runs Overview')
# Out:
# Text(0.5, 1.0, 'Virat Kohali and Rohit Sharma Runs Overview')

# %%
# colors(hex) and line(width and style) and marker(size)
plt.plot(df['index'], df['V Kohli'], c="blue", linewidth=2, linestyle="solid", marker="o", markerfacecolor="red")
plt.plot(df['index'], df['RG Sharma'], c = "red", linewidth=2, marker="o")
plt.xlabel("Year")
plt.ylabel('Total Runs')
plt.title('Virat Kohali and Rohit Sharma Runs Overview')
# Out:
# Text(0.5, 1.0, 'Virat Kohali and Rohit Sharma Runs Overview')

# %%
# legend -> location
plt.plot(df['index'], df['V Kohli'], c="blue", linewidth=2, linestyle="solid", marker="o", label="Virat Kohli")
plt.plot(df['index'], df['RG Sharma'], c = "red", linewidth=2, marker="o", label="Rohit Sharma")
plt.xlabel("Year")
plt.ylabel('Total Runs')
plt.title('Virat Kohali and Rohit Sharma Runs Overview')
plt.legend()

# %%
# limiting axes
plt.plot(df['index'], df['V Kohli'], c="blue", linewidth=2, linestyle="solid", marker="o", label="Virat Kohli")
plt.plot(df['index'], df['RG Sharma'], c = "red", linewidth=2, marker="o", label="Rohit Sharma")
plt.xlabel("Year")
plt.ylabel('Total Runs')
plt.title('Virat Kohali and Rohit Sharma Runs Overview')
# plt.ylim(0, 500)
# plt.xlim(2008 , 2014)
plt.legend()

# %%
# grid
plt.plot(df['index'], df['V Kohli'], c="blue", linewidth=2, linestyle="solid", marker="o", label="Virat Kohli")
plt.plot(df['index'], df['RG Sharma'], c = "red", linewidth=2, marker="o", label="Rohit Sharma")
plt.xlabel("Year")
plt.ylabel('Total Runs')
plt.title('Virat Kohali and Rohit Sharma Runs Overview')
plt.legend()
plt.grid()

# %%
# marker and markersize
plt.plot(df['index'], df['V Kohli'], c="blue", linewidth=2, linestyle="solid", marker="d", label="Virat Kohli", markersize= 10)
plt.plot(df['index'], df['RG Sharma'], c = "red", linewidth=2, marker="o", label="Rohit Sharma")
plt.xlabel("Year")
plt.ylabel('Total Runs')
plt.title('Virat Kohali and Rohit Sharma Runs Overview')
plt.legend()

# %%
# show
plt.plot(df['index'], df['V Kohli'], c="blue", linewidth=2, linestyle="solid", marker="d", label="Virat Kohli", markersize= 10)
plt.plot(df['index'], df['RG Sharma'], c = "red", linewidth=2, marker="o", label="Rohit Sharma")
plt.xlabel("Year")
plt.ylabel('Total Runs')
plt.title('Virat Kohali and Rohit Sharma Runs Overview')
plt.legend()
plt.show()

# %% [markdown]
# # Scatter Plots

# %% [markdown]
# - Bivariate Analysis
# - numerical vs numerical
# - Use case - Finding correlation

# %%
# plt.scatter simple function
x = [1,2,3,4,5,6,7,8,9]
y = [10,20,33,45,40,61,27,58,79]
plt.scatter(x , y)
plt.xlabel('study hours')
plt.ylabel('marks')
plt.show()

# %%
# plt.scatter on pandas data (batter.csv)
df = pd.read_csv('./Datasets/batter.csv')
df
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
plt.scatter(df['avg'], df['strike_rate'])
plt.xlabel('Average Runs')
plt.ylabel('Strike Rate')
plt.show()

# %%
# size  (sns.load_dataset(tips) and perfoem on this dataset )
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.plot(df['tip'], df['total_bill'], linestyle="none", marker="o", markersize = 5)

# %%
# scatterplot using plt.plot
# faster

# %% [markdown]
#  # Bar chart
# - Bivariate Analysis
# - Numerical vs Categorical
# - Use case - Aggregate analysis of groups

# %%
# simple bar chart
x = [1,2,3,4,5,6,7,8,9]
y = [10,30,20,40,60,40,50,60,70]
plt.bar(x , y)
plt.xlabel('exp')
plt.ylabel('salary')
# Out:
# Text(0, 0.5, 'salary')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# bar chart using data
df= pd.read_csv('Datasets/sharma-kohli.csv')
plt.bar(df['index'], df['RG Sharma'])
# Out:
# <BarContainer object of 10 artists>

# %%
df.head(5)
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
plt.bar(df['index'], df['V Kohli'])
# Out:
# <BarContainer object of 10 artists>

# %%
# horizontal bar chart
plt.barh(df['index'], df['V Kohli'])
# Out:
# <BarContainer object of 10 artists>

# %%
# color and label
plt.bar(df['index'], df['V Kohli'], color = ['red', 'blue', 'green'])
plt.xlabel('Year')
plt.ylabel('total Runs ')
plt.title('Total Year wise Runs ')
# Out:
# Text(0.5, 1.0, 'Total Year wise Runs ')

# %%
# xticks
totalMarks = [80,50,58,87,40,90,69,78,99,64]
studentName = ['Vikashbhaibhaibhaibhaibhai', 'vijayvijayvijayvijayvijayvijay', 'manishmanishmanishmanish','Vikashbhaibhaibha1ibhaibhai', 'vijayvijayvijayvijayvijayvijay', 'manishmanishma1nishmanish','Vikashbhaibhaibhaibhaibhai', 'vijayvijayvijayvijayvijayvijay', 'manishmanishmanishmanish',"RajuBhai"]
plt.bar(studentName , totalMarks)
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# ### Histogram
# - Univariate Analysis
# - Numerical col
# - Use case - Frequency Count

# %%
# simple data
totalMarks = [10,10,20,20,20,21,30,30,30,40,40,50,50,50,50]
plt.hist(totalMarks, bins=5)
plt.show()

# %%
# on some data (vk.csv)
df = pd.read_csv('Datasets/vk.csv')
plt.hist(df['batsman_runs'], bins=[0,30,60,90, 120])
# Out:
# (array([78., 42., 15.,  6.]),
#  array([  0.,  30.,  60.,  90., 120.]),
#  <BarContainer object of 4 artists>)

# %%
# handling bins

# %% [markdown]
# # Pie Chart
# - Univariate/Bivariate Analysis
# - Categorical vs numerical
# - Use case - To find contibution on a standard scale

# %%
# simple data
a = [50,30,20,60,100]
b = ['abhay', 'vijay','raju', 'rahul', 'rohit']
plt.pie(a)
plt.show()

# %%
# dataset (gayle-175.csv)
df = pd.read_csv('gayle-175.csv')
df
# Out:
#           batsman  batsman_runs
# 0  AB de Villiers            31
# 1        CH Gayle           175
# 2       R Rampaul             0
# 3       SS Tiwary             2
# 4      TM Dilshan            33
# 5         V Kohli            11

# %%
plt.pie(df['batsman_runs'], labels=df['batsman'])
plt.show()

# %%
# use autopct for % 
plt.pie(df['batsman_runs'], labels=df['batsman'], autopct='%0.2f%%')
plt.show()

# %%
# use Colors
plt.pie(df['batsman_runs'], labels=df['batsman'], colors=['red', 'green', 'pink', 'yellow', 'gold'])
plt.show()

# %%
# explode & shadow
plt.pie(df['batsman_runs'], labels=df['batsman'], explode=[0.1,0,0, 0, 0, 0], shadow=True)
plt.show()

# %% [markdown]
# # Changing styles

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')
# xticks
totalMarks = [80,50,58,87,40,90,69,78,99,64]
studentName = ['Vikashbhaibhaibhaibhaibhai', 'vijayvijayvijayvijayvijayvijay', 'manishmanishmanishmanish','Vikashbhaibhaibha1ibhaibhai', 'vijayvijayvijayvijayvijayvijay', 'manishmanishma1nishmanish','Vikashbhaibhaibhaibhaibhai', 'vijayvijayvijayvijayvijayvijay', 'manishmanishmanishmanish',"RajuBhai"]
plt.bar(studentName , totalMarks)
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# # Save figure

# %%
plt.pie(df['batsman_runs'], labels=df['batsman'], explode=[0.1,0,0, 0, 0, 0], shadow=True)
plt.savefig('piechart.png')
plt.show()

# %% [markdown]
# # Checkout Doc on website
