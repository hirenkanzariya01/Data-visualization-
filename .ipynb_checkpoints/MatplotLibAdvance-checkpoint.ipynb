# %%
# import library 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  # Colored Scatterplots

# %%
df = pd.read_csv('Datasets/iris.csv')
df.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 128  129            6.4           2.8            5.6           2.1
# 9     10            4.9           3.1            1.5           0.1
# 114  115            5.8           2.8            5.1           2.4
# 123  124            6.3           2.7            4.9           1.8
# 3      4            4.6           3.1            1.5           0.2
#
#             Species
# 128  Iris-virginica
# 9       Iris-setosa
# 114  Iris-virginica
# 123  Iris-virginica
# 3       Iris-setosa

# %%
df['Species'] = df['Species'].replace({"Iris-virginica":0,"Iris-versicolor":1, "Iris-setosa":2 })

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        2
# 1   2            4.9           3.0            1.4           0.2        2
# 2   3            4.7           3.2            1.3           0.2        2
# 3   4            4.6           3.1            1.5           0.2        2
# 4   5            5.0           3.6            1.4           0.2        2

# %%
# cmap and alpha 
plt.scatter(df['SepalLengthCm'], df['PetalLengthCm'], c=df['Species'], alpha=0.9)

# %%
# colorbar
plt.figure(figsize=(18, 10))
plt.scatter(df['SepalLengthCm'], df['PetalLengthCm'], c=df['Species'],  linewidth=2, linestyle="solid",  s=50)
plt.colorbar()

# %%
# Plot size
plt.figure(figsize=(15, 10))
plt.scatter(df['SepalLengthCm'], df['PetalLengthCm'], c=df['Species'], cmap='winter')
plt.colorbar()

# %%
# Annotations  use 
batters = pd.read_csv('Datasets/batter.csv')
newdf = batters.sample(25)

# %%
newdf.head()
# Out:
#              batter  runs        avg  strike_rate
# 275  Mohammed Siraj    96  13.714286    86.486486
# 113         VR Iyer   552  27.600000   116.455696
# 197         AS Raut   194  21.555556   112.790698
# 149          JJ Roy   329  29.909091   124.621212
# 524        VG Arora     5   2.500000    35.714286

# %%
newdf.iloc[3]['runs']
# Out:
# np.int64(329)

# %%
plt.figure(figsize=(18, 10))
plt.scatter(newdf['avg'], newdf['runs'])
plt.title('Players Avg And Runs')
plt.xlabel('AVG')
plt.ylabel('RUNS')
for i in range(25):
    plt.text(newdf.iloc[i]['avg'], newdf.iloc[i]['runs'], newdf.iloc[i]['batter'], fontdict={"size":15})

# %%
x = [1,2,3,4]
y = [5,6,7,8]
plt.scatter(x , y)
plt.text(1, 5, "point 1", fontdict={'color':'red', 'size':12})
plt.text(2, 6, "point 2")
plt.text(3, 7, "point 3")
plt.text(4, 8, "point 4")
# Out:
# Text(4, 8, 'point 4')

# %%
# Horizontal and Vertical lines
plt.figure(figsize=(10, 6))
plt.scatter(df['SepalLengthCm'], df['PetalLengthCm'], c=df['Species'], cmap='winter')
plt.colorbar()
plt.title('irs Datasets')
plt.xlabel('PetalLengthCm')
plt.ylabel('SepalLengthCm')
plt.axhline(5, color="red")
plt.axvline(7,color="green" )
plt.show()

# %%
x = [1,2,3,4,5]
y = [10,20,25,20,30]

# %%
# A Diff way to plot graph (subplots, add_subplots)
fig , ax = plt.subplots(ncols=3, nrows=3)
ax[0, 0].plot(x , y)
ax[0, 1].pie(x)
ax[1, 0].scatter(x , y)
ax[1, 1].bar(x, y)
ax[0, 2].scatter(x , y)
ax[1, 2].bar(x, y)

ax[0, 0].set_title('income')
ax[0,0].set_xlabel('Months')
ax[0,0].set_ylabel('income')

ax[0,1].set_title('income')
ax[0,1].set_xlabel('Months')
ax[0,1].set_ylabel('income')
ax[1,1].set_xlabel('Test')
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax1.plot(x , y)

ax2 = fig.add_subplot(2,2, 2)
ax2.pie(x)

ax3 = fig.add_subplot(2,2, 3)
ax3.bar(x , y)

ax4 = fig.add_subplot(2,2, 4)

# %%
# 3d scatterploats
x = [2,5,10,20]
y = [0,3,16,4]
z = [0,12,4,16]



fig = plt.figure()
fig.add_subplot(projection='3d')
plt.plot(x , y , z)
plt.xlabel('---X---')
plt.ylabel('---Y---')
plt.title('3D Ploat')
# plt.zlabel('---Z---')
# Out:
# Text(0.5, 0.92, '3D Ploat')

# %%
df = pd.read_csv('Datasets/batter.csv')
newdf = df.sample(200)

fig = plt.figure()
fig.add_subplot(projection='3d')
plt.scatter( newdf['avg'] ,newdf['runs'] , newdf['strike_rate'])

# %%
df = pd.read_csv('Datasets/batter.csv')
newdf = df.sample(200)
newdf.head()
# Out:
#                       batter  runs        avg  strike_rate
# 35                   WP Saha  2427  25.281250   124.397745
# 498  JPR Scantlebury-Searles     8   8.000000   133.333333
# 471               K Upadhyay    12        NaN   133.333333
# 382             Basil Thampi    32  32.000000    86.486486
# 54             Mandeep Singh  1692  21.417722   120.684736

# %%
fig = plt.figure(figsize=(15, 15))
ax = plt.subplot(projection='3d')
ax.scatter3D(newdf['runs'], newdf['avg'], newdf['strike_rate'])

ax.set_xlabel('---X Label---')
ax.set_ylabel('--- Y Label ----')
ax.set_zlabel('-- Z Label --')
# Out:
# Text(0.5, 0, '-- Z Label --')

# %%
# 3D surface Plot
x = np.linspace(-10,10, 100)
y = np.linspace(-10, 10, 100)
xx, yy = np.meshgrid(x , y)
z = xx*xx + yy*yy 
fig = plt.figure(figsize=(18,8))
ax = plt.subplot(projection = "3d")
a = ax.plot_surface(xx , yy , z, cmap='viridis')
plt.colorbar(a)

# %%
x = np.linspace(-10,10, 100)
y = np.linspace(-10, 10, 100)
xx, yy = np.meshgrid(x , y)

z = np.cos(xx) + np.cos(yy)

fig = plt.figure(figsize=(12,8))
ax = plt.subplot(projection='3d')
ax.plot_surface(xx , yy , z, cmap='viridis')

ax.set_xlabel('---X Label---')
ax.set_ylabel('--- Y Label ----')
ax.set_zlabel('-- Z Label --')
# Out:
# Text(0.5, 0, '-- Z Label --')

# %%
# contour plots
x = np.linspace(-10,10, 100)
y = np.linspace(-10, 10, 100)
xx, yy = np.meshgrid(x , y)
z = np.cos(xx) + np.cos(yy)
fig = plt.figure(figsize=(8,6))
ax = plt.subplot()
a = ax.contourf(xx , yy , z, cmap='viridis')
plt.colorbar(a)

# %%
# pandas plot function
newdf
# Out:
#             batter  runs        avg  strike_rate
# 161     SP Goswami   293  14.650000    95.439739
# 53       MK Tiwary  1695  28.728814   113.834788
# 69      D Padikkal  1260  28.000000   119.205298
# 292     WPUJC Vaas    81  10.125000   110.958904
# 270     SD Chitnis    99  14.142857   107.608696
# 559   Harshit Rana     2   2.000000   100.000000
# 61     S Badrinath  1441  30.659574   115.742972
# 497       P Chopra     8   8.000000   133.333333
# 366  KW Richardson    36  12.000000    92.307692
# 14       SR Watson  3880  30.793651   134.163209

# %%
# df = pd.Series([10,20,30,10,20,50])
# df.plot( xlabel="plot number", ylabel='sels')
# Out:
# <Axes: xlabel='plot number', ylabel='sels'>

# %%
tips.head()
gropedData = tips.groupby('time')['total_bill'].sum()

# %%
# 2d plot
dataset = 'https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv'
df = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')
df.head()
tempdf = df.head()
tempdf['newData1'] = tempdf['FB']
tempdf['newData2'] = tempdf['FB']
tempdf['newData3'] = tempdf['FB']
tempdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      5 non-null      object
#  1   MSFT      5 non-null      float64
#  2   FB        5 non-null      float64
#  3   AAPL      5 non-null      float64
#  4   newData1  5 non-null      float64
#  5   newData2  5 non-null      float64
#  6   newData3  5 non-null      float64
# dtypes: float64(6), object(1)
# memory usage: 412.0+ bytes

# %%
tempdf[['FB', 'AAPL', 'MSFT','newData1', 'newData2', 'newData3']].plot(kind='bar' ,subplots=True, figsize=(5,10))
# Out:
# array([<Axes: title={'center': 'FB'}>, <Axes: title={'center': 'AAPL'}>,
#        <Axes: title={'center': 'MSFT'}>,
#        <Axes: title={'center': 'newData1'}>,
#        <Axes: title={'center': 'newData2'}>,
#        <Axes: title={'center': 'newData3'}>], dtype=object)
