# %% [markdown]
# 📊 MATPLOTLIB PRACTICE QUESTIONS
#
# 🟢 BEGINNER LEVEL
#
# 1. Plot a bar chart of Units_Sold for each Model.
# 2. Create a pie chart showing percentage share of Revenue_EUR.
# 3. Draw a line chart of Avg_Price_EUR for all models.
# 4. Plot a histogram of Units_Sold.
# 5. Create a scatter plot between Avg_Price_EUR and Units_Sold.

# %% [markdown]
# 🟡 INTERMEDIATE LEVEL
#
# 6. Find the model with highest revenue and show it using a bar chart.
# 7. Plot Revenue_EUR vs Avg_Price_EUR and analyze correlation.
# 8. Create subplots to compare:
#    - Units_Sold
#    - Revenue_EUR
#
# 9. Plot top 3 models by Units_Sold.
# 10. Create a horizontal bar chart sorted by Revenue_EUR.

# %% [markdown]
# 🔵 DATA ANALYSIS LEVEL
#
# 11. Create a new column:
#    Revenue_per_Unit = Revenue_EUR / Units_Sold
#    Plot it for each model.
#
# 13. Find which model gives highest Revenue_per_Unit and visualize it.
#
# 14. Analyze relationship:
#    High Price → Low Sales (scatter plot).
#
# 15. Plot BEV_Share vs Units_Sold.
#
# 16. Plot Premium_Share vs Revenue_EUR.
