# %%
import matplotlib.pyplot as plt

# %%
student = ['ajay', 'vivek', 'rohit', 'rahul', 'sumit']
marks = [82,45,68,78,100]

# %%
plt.bar(student , marks, color="orange")
plt.title("Std 10th Marks ")
plt.xlabel("Student Name")
plt.ylabel('Total Marks ')
plt.show()
